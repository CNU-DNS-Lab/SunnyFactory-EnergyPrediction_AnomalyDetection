# %%
import warnings
import pandas as pd
from utils import *

warnings.filterwarnings('ignore')

# %%
First = pd.DataFrame(columns=range(0,20), index=range(0,8))
Second = pd.DataFrame(columns=range(0,20), index=range(0,8))
Third = pd.DataFrame(columns=range(0,20), index=range(0,8))

# %%
First.loc[0] = ['외부', '복도', '복도', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                '화장실', '외부', '외부', '외부', '외부', '외부', '복도', '복도', '복도', '외부']
First.loc[1] = ['외부', '실험실', '실험실', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                '복도', '복도', '복도', '복도', '복도', '복도', '복도', '실험실', '실험실', '외부']
First.loc[2] = ['외부', '실험실', '실험실', '복도', '교수실', '교수실', '준비실', '실험실', '실험실', '실험실',
                '연구실', '준비실', '교수실', '교수실', '준비실', '사무실', '복도', '실험실', '실험실', '외부']
First.loc[3] = ['외부', '외부', '공정실', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                '외부', '외부', '외부', '외부', '외부', '외부', '복도', '실험실', '외부', '외부']
First.loc[4] = ['외부', '외부', '공정실', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                '외부', '외부', '외부', '외부', '외부', '외부', '복도', '실험실', '외부', '외부']
First.loc[5] = ['외부', '외부', '지원실', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                '화장실', '휴게실', '외부', '외부', '외부', '외부', '복도', '연구실', '연구실', '실험실']
First.loc[6] = ['학생회실', '학생회실', '지원실', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '실험실']
First.loc[7] = ['실험실', '실험실', '분석실', '복도', '세미나실', '세미나실', '연구실', '표본실', '교수실', '사무실',
                '정독실', '정독실', '연구실', '설계실', '서버실', '학생회실', '복도', '실험실', '실험실', '실험실']
print('='*10, 'First', '='*10)
print_unique(First)


Second.loc[0] = ['외부', '복도', '복도', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                 '화장실', '외부', '외부', '외부', '외부', '외부', '복도', '복도', '복도', '외부']
Second.loc[1] = ['외부', '실험실', '실험실', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                 '복도', '복도', '복도', '복도', '복도', '복도', '복도', '실험실', '실험실', '외부']
Second.loc[2] = ['외부', '실험실', '실험실', '복도', '사무실', '교수실', '기업체', '교수회의실', '준비실', '교수실',
                 '교수실', '연구실', '행정실', '교수회의실', '교수실', '준비실', '복도', '실험실', '실험실', '외부']
Second.loc[3] = ['외부', '외부', '외부', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                 '외부', '외부', '외부', '외부', '외부', '외부', '복도', '외부', '외부', '외부']
Second.loc[4] = ['외부', '외부', '외부', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                 '외부', '외부', '외부', '외부', '외부', '외부', '복도', '외부', '외부', '외부']
Second.loc[5] = ['강의실', '강의실', '강의실', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                 '화장실', '외부', '외부', '외부', '외부', '외부', '복도', '강의실', '강의실', '강의실']
Second.loc[6] = ['강의실', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                 '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도', '복도']
Second.loc[7] = ['강의실', '강의실', '강의실', '복도', '교수실', '교수실', '교수실', '교수실', '교수실', '사무실',
                 '사무실', '교수회의실', '교수실', '연구실', '교수실', '교수실', '복도', '강의실', '강의실', '강의실']
print('='*10, 'Second', '='*10)
print_unique(Second)


Third.loc[0] = ['외부', '복도', '복도', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                '화장실', '외부', '외부', '외부', '외부', '외부', '복도', '복도', '복도', '외부']
Third.loc[1] = ['외부', '실험실', '실험실', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                '복도', '복도', '복도', '복도', '복도', '복도', '복도', '실험실', '실험실', '외부']
Third.loc[2] = ['외부', '실험실', '실험실', '복도', '교수실', '준비실', '교수실', '교수실', '교수실', '준비실',
                '준비실', '교수실', '교수실', '교수실', '준비실', '교수실', '복도', '실험실', '실험실', '외부']
Third.loc[3] = ['외부', '외부', '외부', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                '외부', '외부', '외부', '외부', '외부', '외부', '복도', '외부', '외부', '외부']
Third.loc[4] = ['외부', '외부', '외부', '복도', '외부', '외부', '외부', '외부', '외부', '외부',
                '외부', '외부', '외부', '외부', '외부', '외부', '복도', '외부', '외부', '외부']
Third.loc[5] = ['외부', '외부', '외부', '복도', '외부', '외부', '외부', '외부', '외부', '화장실',
                '화장실', '외부', '외부', '외부', '외부', '외부', '복도', '외부', '외부', '외부']
Third.loc[6] = ['외부', '외부', '외부', '복도', '복도', '복도', '복도', '복도', '복도', '복도',
                '복도', '복도', '복도', '복도', '복도', '복도', '복도', '외부', '외부', '외부']
Third.loc[7] = ['외부', '외부', '외부', '복도', '연구실', '연구실', '연구실', '연구실', '연구실', '연구실',
                '세미나실', '세미나실', '교수실', '연구실', '교수실', '교수실', '복도', '외부', '외부', '외부']
print('='*10, 'Third', '='*10)
print_unique(Third)
# Out:
# ========== First ==========
# 유니크 값의 개수 : 18
# 유니크 값 목록
# ['공정실' '교수실' '복도' '분석실' '사무실' '서버실' '설계실' '세미나실' '실험실' '연구실' '외부' '정독실'
#  '준비실' '지원실' '표본실' '학생회실' '화장실' '휴게실']
# ========== Second ==========
# 유니크 값의 개수 : 12
# 유니크 값 목록
# ['강의실' '교수실' '교수회의실' '기업체' '복도' '사무실' '실험실' '연구실' '외부' '준비실' '행정실' '화장실']
# ========== Third ==========
# 유니크 값의 개수 : 8
# 유니크 값 목록
# ['교수실' '복도' '세미나실' '실험실' '연구실' '외부' '준비실' '화장실']

# %%
# First
# 0
First.replace('외부', 0, inplace=True)
# 1
First.replace(['복도','화장실','휴게실'], '공용공간', inplace=True)
# 2
First.replace(['세미나실','정독실','준비실'], '강의지원', inplace=True)
# 3
First.replace(['사무실','지원실'], '행정지원', inplace=True)
# 4
First.replace('학생회실', "학생자율", inplace=True)
# 5
First.replace('서버실', "학술지원", inplace=True)
# 6
First.replace('교수실', "교수연구", inplace=True)
# 7
First.replace(['공정실', '분석실', '설계실','실험실','연구실','표본실'], '연구공간', inplace=True)

# Second
# 0
Second.replace('외부', 0, inplace=True)
# 1
Second.replace(['복도','화장실'], '공용공간', inplace=True)
# 2
Second.replace(['강의실','교수회의실','준비실'], '강의지원', inplace=True)
# 3
Second.replace(['사무실', '행정실','기업체'], '행정지원', inplace=True)
# 4
Second.replace('교수실', "교수연구", inplace=True)
# 5
Second.replace(['실험실', '연구실'], '연구공간', inplace=True)

#Third
# 0
Third.replace('외부', 0, inplace=True)
# 1
Third.replace(['복도','화장실'], '공용공간', inplace=True)
# 2
Third.replace(['세미나실','준비실'], '강의지원', inplace=True)
# 3
Third.replace('교수실', "교수연구", inplace=True)
# 4
Third.replace(['실험실', '연구실'], '연구공간', inplace=True)

print('='*10, 'First', '='*10)
print_unique(First)
print('='*10, 'Second', '='*10)
print_unique(Second)
print('='*10, 'Third', '='*10)
print_unique(Third)
# Out:
# ========== First ==========
# 유니크 값의 개수 : 8
# 유니크 값 목록
# ['0' '강의지원' '공용공간' '교수연구' '연구공간' '학생자율' '학술지원' '행정지원']
# ========== Second ==========
# 유니크 값의 개수 : 6
# 유니크 값 목록
# ['0' '강의지원' '공용공간' '교수연구' '연구공간' '행정지원']
# ========== Third ==========
# 유니크 값의 개수 : 5
# 유니크 값 목록
# ['0' '강의지원' '공용공간' '교수연구' '연구공간']

# %%
Concat = pd.concat([Third, Second, First])

check_path('../temp')
First.to_csv('../temp/dataset_03[1층].csv', index=False)
Second.to_csv('../temp/dataset_04[2층].csv', index=False)
Third.to_csv('../temp/dataset_05[3층].csv', index=False)
Concat.to_csv('../temp/dataset_06[전체건물].csv', index=False)
